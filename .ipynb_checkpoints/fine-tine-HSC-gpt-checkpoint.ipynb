# %%
import openai
import pandas as pd

# %%
df = pd.read_excel('HSC_Data.xlsx')

# %%
df
# Out:
#                                         Prompt  \
# 0   Create a Paper 1 Short Answer HSC question
# 1   Create a Paper 1 Short Answer HSC question
# 2   Create a Paper 1 Short Answer HSC question
# 3   Create a Paper 1 Short Answer HSC question
# 4   Create a Paper 1 Short Answer HSC question
# 5   Create a Paper 1 Short Answer HSC question
# 6   Create a Paper 1 Short Answer HSC question
# 7   Create a Paper 1 Short Answer HSC question
# 8   Create a Paper 1 Short Answer HSC question
# 9   Create a Paper 1 Short Answer HSC question
# 10  Create a Paper 1 Short Answer HSC question
# 11  Create a Paper 1 Short Answer HSC question
# 12  Create a Paper 1 Short Answer HSC question
# 13  Create a Paper 1 Short Answer HSC question
# 14  Create a Paper 1 Short Answer HSC question
# 15  Create a Paper 1 Short Answer HSC question
# 16  Create a Paper 1 Short Answer HSC question
# 17  Create a Paper 1 Short Answer HSC question
# 18  Create a Paper 1 Short Answer HSC question
# ...

# %%
df['response_strings'] = df.apply(lambda row: f"""Title: {row['Title']}
Text: {row['Text']}
Author: {row['Author']}
Type: {row['Type']}
Question: {row['Question']}
Marks: {row['Marks']}""", axis=1)

# %%
df
# Out:
#                                         Prompt  \
# 0   Create a Paper 1 Short Answer HSC question
# 1   Create a Paper 1 Short Answer HSC question
# 2   Create a Paper 1 Short Answer HSC question
# 3   Create a Paper 1 Short Answer HSC question
# 4   Create a Paper 1 Short Answer HSC question
# 5   Create a Paper 1 Short Answer HSC question
# 6   Create a Paper 1 Short Answer HSC question
# 7   Create a Paper 1 Short Answer HSC question
# 8   Create a Paper 1 Short Answer HSC question
# 9   Create a Paper 1 Short Answer HSC question
# 10  Create a Paper 1 Short Answer HSC question
# 11  Create a Paper 1 Short Answer HSC question
# 12  Create a Paper 1 Short Answer HSC question
# 13  Create a Paper 1 Short Answer HSC question
# 14  Create a Paper 1 Short Answer HSC question
# 15  Create a Paper 1 Short Answer HSC question
# 16  Create a Paper 1 Short Answer HSC question
# 17  Create a Paper 1 Short Answer HSC question
# 18  Create a Paper 1 Short Answer HSC question
# ...

# %%
print(df.response_strings.values[0])
# Out:
# Title: Boomerangs in a Thunderstorm
# Text: The clouds are so low that I imagine a puffy hand, reaching out and sending a boomerang off-course. But here we are, like it should be, an uncle and his nephew, throwing boomerangs, tuning the wind. Thunder cracking. Whooping shapes dance across the overcast sky. My lungs are full of the spirits of rain, and it is not long before we are both soaked, riding the storm. Our boomerangs scale the breeze . . . you should always throw a ‘returning’ boomerang into the wind . . . like a sail. On the summit of the sacred owl mountain, Coot-tha Dreaming, throwing boomerangs in a thunderstorm
# Author: SAMUEL WAGAN WATSON
# Type: Poem
# Question: Explain how Boomerangs in a Thunderstorm represents an intense moment.
# Marks: 3

# %%
system_prompt = "You are an assistant that, when asked to create a paper 1 short answer HSC question, provides the title of a text, the actual text itself, the author of the text, the text type, the actual question about the text for students to answer and the reasonable amount of marks the question is worth (max 6 marks)."

# %%
all_conversations = []

for idx, row in df.iterrows():
    all_conversations.append({"messages": [{"role": "system", "content": system_prompt},
                                           {"role": "user", "content": row["Prompt"]},
                                           {"role": "assistant", "content": row['response_strings']}]})

# %%
all_conversations
# Out:
# [{'messages': [{'role': 'system',
#     'content': 'You are an assistant that, when asked to create a paper 1 short answer HSC question, provides the title of a text, the actual text itself, the author of the text, the text type, the actual question about the text for students to answer and the reasonable amount of marks the question is worth (max 6 marks).'},
#    {'role': 'user', 'content': 'Create a Paper 1 Short Answer HSC question'},
#    {'role': 'assistant',
# ...

# %%
import json

with open('instances.jsonl', 'w') as f:
    for conversation in all_conversations:
        json.dump(conversation, f)
        f.write('\n')

# %%
from dotenv import load_dotenv
import os

# Load variables from .env file into environment
load_dotenv()

# Access environment variables
openai_api_key = os.environ.get('OPENAI_API_KEY')

# %%
client = openai.OpenAI(api_key=openai_api_key)

# %%
with open('instances.jsonl', 'rb') as f:
    response = client.files.create(file=f, purpose='fine-tune')

# %%
response
# Out:
# FileObject(id='file-6OCjBbxM7oYovBj62koHEKqZ', bytes=116911, created_at=1716103246, filename='instances.jsonl', object='file', purpose='fine-tune', status='processed', status_details=None)

# %%
file_id = 'file-6OCjBbxM7oYovBj62koHEKqZ'

# %%
response = client.fine_tuning.jobs.create(
    training_file=file_id,
    model='gpt-3.5-turbo'
)

# %%
response
# Out:
# FineTuningJob(id='ftjob-t90BWhd7xcojdF7k9of4pycS', created_at=1716103261, error=Error(code=None, message=None, param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(n_epochs='auto', batch_size='auto', learning_rate_multiplier='auto'), model='gpt-3.5-turbo-0125', object='fine_tuning.job', organization_id='org-n4HFQOFlu8OtsCxjAlYxcnHN', result_files=[], seed=1838969123, status='validating_files', trained_tokens=None, training_file='file-6OCjBbxM7oYovBj62koHEKqZ', validation_file=None, estimated_finish=None, integrations=[], user_provided_suffix=None)

# %%
job_id = 'ftjob-t90BWhd7xcojdF7k9of4pycS'

# %%
job_id
# Out:
# 'ftjob-t90BWhd7xcojdF7k9of4pycS'

# %%
client.fine_tuning.jobs.list(limit=1)
# Out:
# SyncCursorPage[FineTuningJob](data=[FineTuningJob(id='ftjob-t90BWhd7xcojdF7k9of4pycS', created_at=1716103261, error=Error(code=None, message=None, param=None), fine_tuned_model='ft:gpt-3.5-turbo-0125:personal::9QVEAIcy', finished_at=1716103593, hyperparameters=Hyperparameters(n_epochs=3, batch_size=1, learning_rate_multiplier=2), model='gpt-3.5-turbo-0125', object='fine_tuning.job', organization_id='org-n4HFQOFlu8OtsCxjAlYxcnHN', result_files=['file-A01hWlFYZ10GQ6ry1oOQ4Tp2'], seed=1838969123, status='succeeded', trained_tokens=77052, training_file='file-6OCjBbxM7oYovBj62koHEKqZ', validation_file=None, estimated_finish=None, integrations=[], user_provided_suffix=None)], object='list', has_more=True)

# %%
status = client.fine_tuning.jobs.retrieve(job_id)

# %%
status
# Out:
# FineTuningJob(id='ftjob-t90BWhd7xcojdF7k9of4pycS', created_at=1716103261, error=Error(code=None, message=None, param=None), fine_tuned_model='ft:gpt-3.5-turbo-0125:personal::9QVEAIcy', finished_at=1716103593, hyperparameters=Hyperparameters(n_epochs=3, batch_size=1, learning_rate_multiplier=2), model='gpt-3.5-turbo-0125', object='fine_tuning.job', organization_id='org-n4HFQOFlu8OtsCxjAlYxcnHN', result_files=['file-A01hWlFYZ10GQ6ry1oOQ4Tp2'], seed=1838969123, status='succeeded', trained_tokens=77052, training_file='file-6OCjBbxM7oYovBj62koHEKqZ', validation_file=None, estimated_finish=None, integrations=[], user_provided_suffix=None)

# %%
model_id = 'ft:gpt-3.5-turbo-0125:personal::9QVEAIcy'

# %%
response = client.chat.completions.create(
    model=model_id,
    messages=[{"role": "system", "content": system_prompt}]
).choices[0].message.content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 3
#       1 response = client.chat.completions.create(
#       2     model=model_id,
# ----> 3     messages=messages
#       4 ).choices[0].message.content
#
# NameError: name 'messages' is not defined
